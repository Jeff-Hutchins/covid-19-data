# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Total Cases Vs Deaths

# %%
counties = pd.read_csv('us-counties.csv')
states = pd.read_csv('us-states.csv')

# %%
states[states.date == '2020-03-27'].sum()
# Out:
# date      2020-03-272020-03-272020-03-272020-03-272020-0...
# state     AlabamaAlaskaArizonaArkansasCaliforniaColorado...
# fips                                                   1693
# cases                                                102648
# deaths                                                 1649
# dtype: object

# %%
counties[counties.date == '2020-03-27'].sum()
# Out:
# date      2020-03-272020-03-272020-03-272020-03-272020-0...
# county    AutaugaBaldwinBlountBullockButlerCalhounChambe...
# state     AlabamaAlabamaAlabamaAlabamaAlabamaAlabamaAlab...
# fips                                            5.21889e+07
# cases                                                102913
# deaths                                                 1652
# dtype: object

# %%
states[states.state == 'District of Columbia']
# Out:
#             date                 state  fips  cases  deaths
# 353   2020-03-07  District of Columbia    11      1       0
# 387   2020-03-08  District of Columbia    11      1       0
# 422   2020-03-09  District of Columbia    11      4       0
# 459   2020-03-10  District of Columbia    11      4       0
# 500   2020-03-11  District of Columbia    11     10       0
# 546   2020-03-12  District of Columbia    11     10       0
# 594   2020-03-13  District of Columbia    11     10       0
# 645   2020-03-14  District of Columbia    11     16       0
# 697   2020-03-15  District of Columbia    11     17       0
# 750   2020-03-16  District of Columbia    11     22       0
# 803   2020-03-17  District of Columbia    11     31       0
# 857   2020-03-18  District of Columbia    11     36       0
# 911   2020-03-19  District of Columbia    11     68       0
# 965   2020-03-20  District of Columbia    11     77       1
# 1019  2020-03-21  District of Columbia    11     98       1
# ...

# %%
counties[counties.county == 'District of Columbia']
# Out:
#              date                county                 state     fips  cases  \
# 682    2020-03-07  District of Columbia  District of Columbia  11001.0      1
# 778    2020-03-08  District of Columbia  District of Columbia  11001.0      1
# 895    2020-03-09  District of Columbia  District of Columbia  11001.0      4
# 1030   2020-03-10  District of Columbia  District of Columbia  11001.0      4
# 1199   2020-03-11  District of Columbia  District of Columbia  11001.0     10
# 1408   2020-03-12  District of Columbia  District of Columbia  11001.0     10
# 1674   2020-03-13  District of Columbia  District of Columbia  11001.0     10
# 1996   2020-03-14  District of Columbia  District of Columbia  11001.0     16
# 2378   2020-03-15  District of Columbia  District of Columbia  11001.0     17
# 2813   2020-03-16  District of Columbia  District of Columbia  11001.0     22
# 3296   2020-03-17  District of Columbia  District of Columbia  11001.0     31
# ...

# %%
len(counties.county.unique())
# Out:
# 1326

# %% [markdown]
# ## Data by County

# %%
counties = pd.read_csv('us-counties.csv')
pop_county = pd
counties.head()
# Out:
#          date     county       state     fips  cases  deaths
# 0  2020-01-21  Snohomish  Washington  53061.0      1       0
# 1  2020-01-22  Snohomish  Washington  53061.0      1       0
# 2  2020-01-23  Snohomish  Washington  53061.0      1       0
# 3  2020-01-24       Cook    Illinois  17031.0      1       0
# 4  2020-01-24  Snohomish  Washington  53061.0      1       0

# %%
#  pd.read_csv('county_population.csv')

# %%
counties[counties.cases < counties.deaths]
# Out:
# Empty DataFrame
# Columns: [date, county, state, fips, cases, deaths]
# Index: []

# %%
counties[counties.cases == counties.deaths]
# Out:
#              date      county         state     fips  cases  deaths
# 606    2020-03-06         Lee       Florida  12071.0      1       1
# 608    2020-03-06  Santa Rosa       Florida  12113.0      1       1
# 689    2020-03-07  Santa Rosa       Florida  12113.0      1       1
# 785    2020-03-08  Santa Rosa       Florida  12113.0      1       1
# 852    2020-03-08      Chelan    Washington  53007.0      1       1
# 902    2020-03-09  Santa Rosa       Florida  12113.0      1       1
# 983    2020-03-09      Chelan    Washington  53007.0      1       1
# 1042   2020-03-10  Santa Rosa       Florida  12113.0      1       1
# 1146   2020-03-10      Chelan    Washington  53007.0      1       1
# 1212   2020-03-11  Santa Rosa       Florida  12113.0      1       1
# 1345   2020-03-11      Chelan    Washington  53007.0      1       1
# 1400   2020-03-12     El Paso      Colorado   8041.0      1       1
# 1424   2020-03-12  Santa Rosa       Florida  12113.0      1       1
# ...

# %%
counties.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21799 entries, 0 to 21798
# Data columns (total 6 columns):
# date      21799 non-null object
# county    21799 non-null object
# state     21799 non-null object
# fips      21464 non-null float64
# cases     21799 non-null int64
# deaths    21799 non-null int64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 1021.9+ KB

# %%
counties.shape
# Out:
# (21799, 6)

# %%
plt.plot(counties.date, counties.cases)

# %%
counties[(counties.state == 'New York') & (counties.date == '2020-03-27')].cases.sum()
# Out:
# 44636

# %%
counties[counties.county == 'New York City']
# Out:
#              date         county     state  fips  cases  deaths
# 416    2020-03-01  New York City  New York   NaN      1       0
# 448    2020-03-02  New York City  New York   NaN      1       0
# 482    2020-03-03  New York City  New York   NaN      2       0
# 518    2020-03-04  New York City  New York   NaN      2       0
# 565    2020-03-05  New York City  New York   NaN      4       0
# 627    2020-03-06  New York City  New York   NaN      5       0
# 715    2020-03-07  New York City  New York   NaN     12       0
# 820    2020-03-08  New York City  New York   NaN     14       0
# 947    2020-03-09  New York City  New York   NaN     20       0
# 1098   2020-03-10  New York City  New York   NaN     37       0
# 1285   2020-03-11  New York City  New York   NaN     52       0
# 1521   2020-03-12  New York City  New York   NaN     96       0
# 1814   2020-03-13  New York City  New York   NaN    155       0
# 2163   2020-03-14  New York City  New York   NaN    269       1
# ...

# %%
counties[counties.county == 'Riverside']
# Out:
#              date     county       state    fips  cases  deaths
# 667    2020-03-07  Riverside  California  6065.0      1       0
# 762    2020-03-08  Riverside  California  6065.0      1       0
# 876    2020-03-09  Riverside  California  6065.0      4       0
# 1008   2020-03-10  Riverside  California  6065.0      4       0
# 1174   2020-03-11  Riverside  California  6065.0      4       0
# 1380   2020-03-12  Riverside  California  6065.0      6       0
# 223    2020-02-19  Bexar  Texas  48029.0      2       0
# 236    2020-02-20  Bexar  Texas  48029.0      2       0
# 250    2020-02-21  Bexar  Texas  48029.0      4       0
# 264    2020-02-22  Bexar  Texas  48029.0      4       0
# 278    2020-02-23  Bexar  Texas  48029.0      4       0
# 293    2020-02-24  Bexar  Texas  48029.0     10       0
# 309    2020-02-25  Bexar  Texas  48029.0     10       0
# 329    2020-02-26  Bexar  Texas  48029.0     10       0
# 349    2020-02-27  Bexar  Texas  48029.0     10       0
# ...

# %% [markdown]
# ## Data by State

# %%
states = pd.read_csv('us-states.csv')

# %%
states.head()
# Out:
#          date       state  fips  cases  deaths
# 0  2020-01-21  Washington    53      1       0
# 1  2020-01-22  Washington    53      1       0
# 2  2020-01-23  Washington    53      1       0
# 3  2020-01-24    Illinois    17      1       0
# 4  2020-01-24  Washington    53      1       0

# %%
states.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1386 entries, 0 to 1385
# Data columns (total 5 columns):
# date      1386 non-null object
# state     1386 non-null object
# fips      1386 non-null int64
# cases     1386 non-null int64
# deaths    1386 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 54.2+ KB

# %%
states.shape
# Out:
# (1386, 5)

# %% [markdown]
# ### Merging another dataset in order to obtain population by state as a column

# %%
state_pop = pd.read_csv('state_population.csv')
state_pop = state_pop[['State', 'Pop', 'density']]
state_pop.columns = ['state', 'population', 'density']

# %%
states = states.merge(state_pop, on='state')

# %%
states.shape
# Out:
# (1361, 7)

# %%
states.fips.unique()
# Out:
# array([53, 17,  6,  4, 25, 55, 48, 31, 49, 41, 12, 36, 44, 13, 33, 37, 34,
#         8, 24, 32, 47, 15, 18, 21, 27, 40, 42, 45, 11, 20, 29, 50, 51,  9,
#        19, 22, 39, 26, 46,  5, 10, 28, 35, 38, 56,  2, 23,  1, 16, 30, 72,
#        54])

# %%
df = pd.read_csv('/Users/jiffy/Downloads/2020_03_29/hospitalization_all_locs_corrected.csv')
pd.options.display.max_columns = None
df.head(1000)
# Out:
#     location_name date_reported  allbed_mean  allbed_lower  allbed_upper  \
# 0         Alabama    2020-02-06     0.000000      0.000000      0.000000
# 1         Alabama    2020-02-07     0.000000      0.000000      0.000000
# 2         Alabama    2020-02-08     0.000000      0.000000      0.000000
# 3         Alabama    2020-02-09     0.000000      0.000000      0.000000
# 4         Alabama    2020-02-10     0.000000      0.000000      0.000000
# 5         Alabama    2020-02-11     0.000000      0.000000      0.000000
# 6         Alabama    2020-02-12     0.000000      0.000000      0.000000
# 7         Alabama    2020-02-13     0.000000      0.000000      0.000000
# 8         Alabama    2020-02-14     0.000000      0.000000      0.000000
# 9         Alabama    2020-02-15     0.000000      0.000000      0.000000
# 10        Alabama    2020-02-16     0.000000      0.000000      0.000000
# 11        Alabama    2020-02-17     0.000000      0.000000      0.000000
# ...
